# %% [markdown]
# <a href="https://colab.research.google.com/github/TAKSAKI/Binalization-by-GoogleColab/blob/master/%E4%BA%8C%E5%80%A4%E5%8C%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files ##自分のパソコンのファイルから画像を選ぶ
x=files.upload()
# Out:
#      <input type="file" id="files-5369bcfd-1e09-45e6-a2e0-e672be33aa1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5369bcfd-1e09-45e6-a2e0-e672be33aa1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 画像処理サンプル_IMG_4295.jpg to 画像処理サンプル_IMG_4295.jpg

# %%
uploaded_file_name = next(iter(x))

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
src = cv2.imread(uploaded_file_name,0)
plt.imshow(src)
plt.gray()

# %%
th, img_th = cv2.threshold(src, 128, 255, cv2.THRESH_BINARY)

# %%
from matplotlib import pyplot as plt ##matplotlibはグラブや画像を描写する

plt.imshow(img_th)
